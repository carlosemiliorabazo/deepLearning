# %% [markdown]
# # Práctica 1: Redes neuronales en Keras (CORREGIDA)

# %% [markdown]
# * Esta práctica nos servirá para saber cómo se crea un modelo en Keras aplicando de una tirada todos los pasos a otro conjunto de datos.
# * Usaremos el conjunto de datos Fashion-MNIST —también precargado en Keras y muy parecido a los que hicimos en clase en cuanto a la preparación requerida de los datos— para poder centrarnos en los pasos relacionados con el modelo.
# * Sabemos que Fashion-MNIST100 es un conjunto de 70K imágenes en escala de grises en 10 categorías.
# * Las imágenes tienen dimensiones (28 x 28) píxeles con valores de 0 a 255 (escala de grises) y usaremos 60K imágenes para entrenar la red y 10K imágenes para evaluar la precisión con la que la red aprende a clasificarlas.

# %% [markdown]
# ## Preparar los datos de Fashion-MNIST

# %%
# %tensorflow_version 2.x
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.7.0

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# * La carga del conjunto de datos devuelve cuatro matrices NumPy.
# * Las matrices `train_images` y `train_labels` son el conjunto de entrenamiento.
# * Las matrices `test_images` y `test_labels` son el conjunto de prueba para evaluar la precisión del modelo.
# * Las etiquetas son una matriz de enteros, que van de `0` a `9`. Estos corresponden a la clase de ropa que representa la imagen:

# %% [markdown]
# Dado que los nombres de clase no se incluyen con el conjunto de datos, podemos crear una lista con ellos para usarlos más adelante al visualizar las imágenes:

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# **Escalamos** los **valores de entrada** en el rango `0-1`:

# %%
train_images = train_images.astype('float32')
test_images = test_images.astype('float32')

train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# Recordemos que es una buena práctica **comprobar** que los **datos tienen la forma que esperamos**:

# %%
print("train_images.shape:",train_images.shape)
print("len(train_labels:",len(train_labels))
print("test_images.shape:",test_images.shape)
print("len(test_labels):",len(test_labels))
# Out:
# train_images.shape: (60000, 28, 28)
# len(train_labels: 60000
# test_images.shape: (10000, 28, 28)
# len(test_labels): 10000

# %% [markdown]
# Y que las muestras y etiquetas son los valores que esperamos:

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
plt.figure(figsize=(12,12))
for i in range(50):
    plt.subplot(10,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# ## Definición de los modelos

# %% [markdown]
# * Dado que los datos son de la misma dimensión y forma, podríamos usar el mismo modelo que en el ejemplo de reconocimiento de números que vimos en clase, pero antes recordemos que en el modelo anterior hemos preprocesado los datos de entrada con la función `numpy.reshape()`.
# * En realidad, Keras nos facilita este paso de reconvertir las muestras de entrada de 28 × 28 a un vector (array) de 784 números (concatenando fila a fila) con el uso de la
# capa `keras.layers.Flatten()`, como se os pedía en la práctica:

# %% [markdown]
# Para facilitar la definición de las diferentes arquitecturas neuronales en cada uno de los 8 casos que me plantea la práctica, me creo vectores con los valores que debo ir utilizando:

# %%
casos = 8
numero_neuronas_primera_capa = [10,10,10,10,512,512,512,512]
funcion_activacion_primera_capa = ['relu','relu','sigmoid','sigmoid','relu','relu','sigmoid','sigmoid']
optimizador =['sgd','rmsprop','sgd','rmsprop','sgd','rmsprop','sgd','rmsprop']
funcion_perdida = ['sparse_categorical_crossentropy', 'sparse_categorical_crossentropy','sparse_categorical_crossentropy',\
                   'sparse_categorical_crossentropy','sparse_categorical_crossentropy','sparse_categorical_crossentropy',\
                   'sparse_categorical_crossentropy','sparse_categorical_crossentropy']
numero_iteraciones = [5,5,5,5,5,5,5,5]
metrica = ['accuracy','accuracy','accuracy','accuracy','accuracy','accuracy','accuracy','accuracy']
models = []

# %% [markdown]
# Decido crearme un vector de modelos de neuronas, uno para cada caso

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten

for caso in range(casos):
  model = Sequential()
  model.add(Flatten(input_shape=(28, 28)))
  model.add(Dense(numero_neuronas_primera_capa[caso], activation=funcion_activacion_primera_capa[caso]))
  model.add(Dense(10, activation='softmax'))
  models.append(model)

# %% [markdown]
# * Podemos comprobar con el método `summary()` que esta capa no requiere parámetros para aplicar la transformación (columna Param #).
# * En general, siempre usaremos esta capa del modelo para hacer esta operación en lugar de redimensionar el tensor de datos antes de la entrada

# %%
for caso in range(casos):
  print("CASO ",caso + 1)
  print("---------------------------------")
  models[caso].summary()
  print("\n\n")
# Out:
# CASO  1
# ---------------------------------
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 10)                7850
#
#  dense_1 (Dense)             (None, 10)                110
#
# =================================================================
# Total params: 7,960
# Trainable params: 7,960
# Non-trainable params: 0
# _________________________________________________________________
#
#
#
# CASO  2
# ---------------------------------
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 10)                7850
#
#  dense_3 (Dense)             (None, 10)                110
#
# =================================================================
# Total params: 7,960
# Trainable params: 7,960
# Non-trainable params: 0
# _________________________________________________________________
#
#
#
# CASO  3
# ---------------------------------
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_4 (Dense)             (None, 10)                7850
#
#  dense_5 (Dense)             (None, 10)                110
#
# =================================================================
# Total params: 7,960
# Trainable params: 7,960
# Non-trainable params: 0
# _________________________________________________________________
#
#
#
# CASO  4
# ---------------------------------
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_3 (Flatten)         (None, 784)               0
#
#  dense_6 (Dense)             (None, 10)                7850
#
#  dense_7 (Dense)             (None, 10)                110
#
# =================================================================
# Total params: 7,960
# Trainable params: 7,960
# Non-trainable params: 0
# _________________________________________________________________
#
#
#
# CASO  5
# ---------------------------------
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_4 (Flatten)         (None, 784)               0
#
#  dense_8 (Dense)             (None, 512)               401920
#
#  dense_9 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
#
#
#
# CASO  6
# ---------------------------------
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_5 (Flatten)         (None, 784)               0
#
#  dense_10 (Dense)            (None, 512)               401920
#
#  dense_11 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
#
#
#
# CASO  7
# ---------------------------------
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_6 (Flatten)         (None, 784)               0
#
#  dense_12 (Dense)            (None, 512)               401920
#
#  dense_13 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
#
#
#
# CASO  8
# ---------------------------------
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_7 (Flatten)         (None, 784)               0
#
#  dense_14 (Dense)            (None, 512)               401920
#
#  dense_15 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Configuración de los modelos

# %% [markdown]
# Antes de que el modelo esté listo para ser entrenado, se requiere especificar el valor de algunos argumentos del método de compilación:

# %%
for caso in range(casos):
  models[caso].compile(optimizer=optimizador[caso], loss=funcion_perdida[caso], metrics=[metrica[caso]])

# %% [markdown]
# * Recordemos que en este paso se especifica la **función de coste** (**loss**) que "dirige" el entrenamiento del modelo en la dirección correcta durante el proceso de entrenamiento.
# * También especificamos el **tipo de optimización** que usaremos **para actualizar los parámetros del modelo** durante el proceso de aprendizaje.
# * Finalmente, se indica la **métrica** que se usará para monitorizar los pasos de entrenamiento y prueba.
# * En este caso  proponemos usar la **precisión** (**accuracy**), es decir, la **fracción** de las **imágenes** que están **clasificadas correctamente**.

# %% [markdown]
# ## Entrenamiento de los modelos

# %% [markdown]
# Ahora los modelos ya están listos para entrenar mediante el método `fit()`, actualizando los parámetros de tal manera que aprenda a asociar imágenes a etiquetas:

# %%
for caso in range(casos):
  print("CASO ",caso + 1)
  print("---------------------------------")
  print("NÚMERO NEURONAS PRIMERA CAPA: ",numero_neuronas_primera_capa[caso])
  print("FUNCIÓN ACTIVACIÓN PRIMERA CAPA: ",funcion_activacion_primera_capa[caso])
  print("FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax")
  print("OPTIMIZADOR: ",optimizador[caso])
  print("FUNCIÓN PÉRDIDA: ",funcion_perdida[caso])
  print("MÉTRICA: ",metrica[caso])
  print("---------------------------------")
  models[caso].fit(train_images, train_labels, epochs=numero_iteraciones[caso])
  print("\n\n")
# Out:
# CASO  1
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  10
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  relu
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  sgd
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.8733 - accuracy: 0.7159
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5665 - accuracy: 0.8041
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5119 - accuracy: 0.8220
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4828 - accuracy: 0.8304
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4649 - accuracy: 0.8365
#
#
#
# CASO  2
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  10
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  relu
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  rmsprop
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6218 - accuracy: 0.7896
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4616 - accuracy: 0.8385
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4362 - accuracy: 0.8488
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4222 - accuracy: 0.8537
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4117 - accuracy: 0.8565
#
#
#
# CASO  3
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  10
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  sgd
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 1.7354 - accuracy: 0.4843
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 1.2274 - accuracy: 0.6298
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 1.0174 - accuracy: 0.6574
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.9050 - accuracy: 0.6790
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.8288 - accuracy: 0.7035
#
#
#
# CASO  4
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  10
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  rmsprop
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.9587 - accuracy: 0.7220
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5416 - accuracy: 0.8206
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4717 - accuracy: 0.8396
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4427 - accuracy: 0.8482
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4256 - accuracy: 0.8541
#
#
#
# CASO  5
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  512
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  relu
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  sgd
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.7053 - accuracy: 0.7728
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.4999 - accuracy: 0.8313
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.4568 - accuracy: 0.8433
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.4307 - accuracy: 0.8515
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.4134 - accuracy: 0.8579
#
#
#
# CASO  6
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  512
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  relu
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  rmsprop
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.4926 - accuracy: 0.8234
# Epoch 2/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3775 - accuracy: 0.8676
# Epoch 3/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3537 - accuracy: 0.8780
# Epoch 4/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3383 - accuracy: 0.8833
# Epoch 5/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3324 - accuracy: 0.8897
#
#
#
# CASO  7
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  512
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  sgd
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 1.1453 - accuracy: 0.6833
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.7110 - accuracy: 0.7627
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.6236 - accuracy: 0.7837
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.5778 - accuracy: 0.8002
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.5477 - accuracy: 0.8097
#
#
#
# CASO  8
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  512
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  rmsprop
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.5090 - accuracy: 0.8173
# Epoch 2/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3827 - accuracy: 0.8605
# Epoch 3/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3453 - accuracy: 0.8752
# Epoch 4/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3196 - accuracy: 0.8831
# Epoch 5/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3027 - accuracy: 0.8898

# %% [markdown]
# * Vemos claramente que, **para los datos de entrenamiento**, el **modelo que mejores valores nos da es el del caso 8**, con la **menor pérdida** y la **mayor precisión**, en torno al 90%. Es lógico que sea uno de los casos con 512 neuronas porque está aprendiendo muchas mas carácterísticas de los datos de entrenamiento que los modelos con 10. Otra cosa serán los valores de pérdida y precisión con datos nuevos, que serán muy altos por **overfitting**.
# * Parece que la combinación de función activación `sigmoid` en la primera capa con optimizador `rmsprop` va bastante bien.
# * El que peor se comporta es el caso 3 con unas pérdidas más altas y una preción de solo el 75%. Parece que la combinación función activación `sigmoid` con optimizador `sgd` no va muy bien. De hecho se ve también con las 512 neuronas con esa misma combinación en el caso 7, que da los valores más bajos de precisión

# %% [markdown]
# ![evolucion perdida por caso.png](data:image/png;base64,...)

# %% [markdown]
# ![evolucion precision por caso.png](data:image/png;base64,...)

# %% [markdown]
# ## Evaluación y mejora de los modelos

# %% [markdown]
# El siguiente paso es comparar el modelo con el conjunto de datos de datos de prueba:

# %%
test_loss = []
test_acc = []
for caso in range(casos):
  test_loss.append(models[caso].evaluate(test_images,  test_labels)[0])
  test_acc.append(models[caso].evaluate(test_images,  test_labels)[1])
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4923 - accuracy: 0.8268
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4923 - accuracy: 0.8268
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4612 - accuracy: 0.8397
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4612 - accuracy: 0.8397
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7661 - accuracy: 0.7554
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7661 - accuracy: 0.7554
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4725 - accuracy: 0.8320
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4725 - accuracy: 0.8320
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4480 - accuracy: 0.8387
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4480 - accuracy: 0.8387
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4305 - accuracy: 0.8673
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4305 - accuracy: 0.8673
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5560 - accuracy: 0.8016
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5560 - accuracy: 0.8016
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3537 - accuracy: 0.8768
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3537 - accuracy: 0.8768

# %%
for caso in range(casos):
  print("CASO ",caso + 1)
  print("---------------------------------")
  print("PERDIDA CON LOS DATOS DE TEST: ",test_loss[caso])
  print("PRECISIÓN CON LOS DATOS DE TEST: ",test_acc[caso])
  print("\n\n")
# Out:
# CASO  1
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.49229565262794495
# PRECISIÓN CON LOS DATOS DE TEST:  0.8267999887466431
#
#
#
# CASO  2
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.4611721336841583
# PRECISIÓN CON LOS DATOS DE TEST:  0.8396999835968018
#
#
#
# CASO  3
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.7661177515983582
# PRECISIÓN CON LOS DATOS DE TEST:  0.7554000020027161
#
#
#
# CASO  4
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.4725416898727417
# PRECISIÓN CON LOS DATOS DE TEST:  0.8320000171661377
#
#
#
# CASO  5
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.44797149300575256
# PRECISIÓN CON LOS DATOS DE TEST:  0.838699996471405
#
#
#
# CASO  6
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.43048295378685
# PRECISIÓN CON LOS DATOS DE TEST:  0.8672999739646912
#
#
#
# CASO  7
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.5560112595558167
# PRECISIÓN CON LOS DATOS DE TEST:  0.8015999794006348
#
#
#
# CASO  8
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.35367831587791443
# PRECISIÓN CON LOS DATOS DE TEST:  0.876800000667572

# %% [markdown]
# ![perdida y precision datos test por caso.png](data:image/png;base64,...)

# %% [markdown]
# Se vuelve a ver que, con los datos de Test, el **caso que mejor se comporta es el caso 8** (con las pérdidas mas bajas y las precisiones mas altas) y el de **peor comportamiento es el del caso 3, de nuevo**. Se ve que no ha habido excesivo sobreentrenamiendo debido al alto número de neuronas en la primera capa. Eso nos hace pensar que el número de neuronas en la primera capa afecta al overfiting menos que, por ejemplo, meter mas capas. (El caso 8 solo ha tenido un poco mas de pérdida con los datos de test, frente a los de entrenamiento y un poco menos de precisión (3pp) con los datos de test frente a los de entrenamiento)

# %% [markdown]
# ## Uso de los modelos para hacer predicciones

# %% [markdown]
# Con el modelo entrenado, podemos empezar a usarlo para hacer predicciones sobre algunas imágenes (usemos por comodidad alguna de las imágenes de prueba que ya tenemos cargadas en el notebook). Lo haremos, como pide el enunciado, con la sexta imagen (la que tiene índice 5 en el array)

# %%
predictions = []
for caso in range(casos):
  predictions.append(models[caso].predict(test_images))

# %% [markdown]
# En `predictions` se ha almacenado la predicción de la etiqueta para cada imagen del conjunto de prueba

# %%
for caso in range(casos):
  print("----------------------------------------------------------")
  print("PREDICCIONES CASO ", caso + 1 , " : ", predictions[caso][5])
  print("VALOR MÁXIMO: ", np.argmax(predictions[caso][5]))
  print("\n\n")
# Out:
# ----------------------------------------------------------
# PREDICCIONES CASO  1  :  [9.7654370e-04 9.8503160e-01 3.3598351e-03 1.1568620e-03 9.4505372e-03
#  1.5294805e-12 2.4228284e-05 1.1014587e-08 3.3549310e-07 2.0940751e-09]
# VALOR MÁXIMO:  1
#
#
#
# ----------------------------------------------------------
# PREDICCIONES CASO  2  :  [2.75113210e-02 9.46713328e-01 4.66493017e-04 1.67831569e-03
#  2.33742297e-02 1.12517886e-11 2.53429957e-04 1.30137914e-12
#  2.89854779e-06 2.07186468e-13]
# VALOR MÁXIMO:  1
#
#
#
# ----------------------------------------------------------
# PREDICCIONES CASO  3  :  [1.8403722e-02 8.7536263e-01 1.0470715e-02 4.4626296e-02 2.0296549e-02
#  1.0678427e-02 1.7604508e-02 9.1579609e-04 8.1686000e-04 8.2444446e-04]
# VALOR MÁXIMO:  1
#
#
#
# ----------------------------------------------------------
# PREDICCIONES CASO  4  :  [4.8217317e-03 9.8853230e-01 9.0851128e-04 4.1008429e-03 4.1051509e-04
#  5.1524785e-05 1.1652216e-03 5.1365400e-06 3.0925751e-06 1.1305261e-06]
# VALOR MÁXIMO:  1
#
#
#
# ----------------------------------------------------------
# PREDICCIONES CASO  5  :  [4.09624167e-03 9.92067456e-01 4.00793011e-04 5.96358615e-04
#  2.62045697e-03 2.32580206e-07 1.94724780e-04 8.13473378e-07
#  2.26872489e-05 1.07523334e-07]
# VALOR MÁXIMO:  1
#
#
#
# ----------------------------------------------------------
# PREDICCIONES CASO  6  :  [2.7381745e-12 1.0000000e+00 1.0062143e-15 4.7960972e-11 3.5499347e-12
#  4.0213627e-22 1.9247189e-14 3.1298462e-22 2.9827918e-18 4.3935559e-26]
# VALOR MÁXIMO:  1
#
#
#
# ----------------------------------------------------------
# PREDICCIONES CASO  7  :  [5.5391183e-03 9.7129685e-01 1.5500812e-03 3.3150527e-03 1.7135521e-02
#  3.5046753e-06 1.1084171e-03 1.0615559e-05 3.9207796e-05 1.5998831e-06]
# VALOR MÁXIMO:  1
#
#
#
# ----------------------------------------------------------
# PREDICCIONES CASO  8  :  [3.2036959e-03 9.9670756e-01 1.4342646e-05 1.0647719e-05 4.5414845e-06
#  9.4637714e-11 5.8634330e-05 6.4722778e-09 5.4782038e-07 2.0715139e-10]
# VALOR MÁXIMO:  1

# %% [markdown]
# El modelo está más seguro que esta imagen son unos pantalones (trousers) que otra cosa. Vemos la etiqueta de clasificación

# %%
test_labels[5]
# Out:
# 1

# %% [markdown]
# Aprovechemos que este conjunto de datos es más rico visualmente para presentar gráficamente cómo de bien o de mal se comporta el modelo. Para ello, usaremos esta función extraída del tutorial de TensorFlow

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)    

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#00FF00")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('black')

# %% [markdown]
# Las etiquetas de predicción correcta las pintaremos de negro y las etiquetas de predicción incorrecta las colorearemos de rojo.El número da el porcentaje (de 100) para la etiqueta predicha.

# %%
def prediccion_un_caso(caso_concreto):
  for caso in range(casos):
    print("----------------------------------------------------------")
    print("PREDICCIONES CASO ", caso + 1 , " FIGURA ", caso_concreto)
    plt.figure(figsize=(6,3))
    plt.subplot(1,2,1)
    plot_image(caso_concreto, predictions[caso][caso_concreto], test_labels, test_images)
    plt.subplot(1,2,2)
    plot_value_array(caso_concreto, predictions[caso][caso_concreto],  test_labels)
    plt.show()
    print("\n\n")

prediccion_un_caso(5)
# Out:
# ----------------------------------------------------------
# PREDICCIONES CASO  1  FIGURA  5
# ----------------------------------------------------------
# PREDICCIONES CASO  2  FIGURA  5
# ----------------------------------------------------------
# PREDICCIONES CASO  3  FIGURA  5
# ----------------------------------------------------------
# PREDICCIONES CASO  4  FIGURA  5
# ----------------------------------------------------------
# PREDICCIONES CASO  5  FIGURA  5
# ----------------------------------------------------------
# PREDICCIONES CASO  6  FIGURA  5
# ----------------------------------------------------------
# PREDICCIONES CASO  7  FIGURA  5
# ----------------------------------------------------------
# PREDICCIONES CASO  8  FIGURA  5

# %% [markdown]
# Vemos claramente como, para el caso del objeto 6, con cada uno de los 8 casos identifica que son unos pantalones con una precisión diferente, siendo el octabo caso el de mayor precisión

# %%
prediccion_un_caso(8)
# Out:
# ----------------------------------------------------------
# PREDICCIONES CASO  1  FIGURA  8
# ----------------------------------------------------------
# PREDICCIONES CASO  2  FIGURA  8
# ----------------------------------------------------------
# PREDICCIONES CASO  3  FIGURA  8
# ----------------------------------------------------------
# PREDICCIONES CASO  4  FIGURA  8
# ----------------------------------------------------------
# PREDICCIONES CASO  5  FIGURA  8
# ----------------------------------------------------------
# PREDICCIONES CASO  6  FIGURA  8
# ----------------------------------------------------------
# PREDICCIONES CASO  7  FIGURA  8
# ----------------------------------------------------------
# PREDICCIONES CASO  8  FIGURA  8

# %% [markdown]
# Vemos para la figura 8 (una sandalia) y el caso 3, realmente no está seguro de que objeto se trata, cuando en el caso 8, está totalmente seguro

# %% [markdown]
# Visualicemos varias imágenes con sus predicciones para los 8 casos. Se debe tener en cuenta que el modelo puede estar equivocado, incluso cuando tiene mucha confianza en la clasificación sobre una de las clases.

# %%
def pintar_conjunto_casos_con_predicciones(num_rows, num_cols, casos):
  num_images = num_rows*num_cols
  for caso in range(casos):
    print("----------------------------------------------------------")
    print("PREDICCIONES CASO ", caso + 1 , " FIGURAS ", num_rows, " x ", num_cols)
    plt.figure(figsize=(2*2*num_cols, 2*num_rows))
    for i in range(num_images):
      plt.subplot(num_rows, 2*num_cols, 2*i+1)
      plot_image(i, predictions[caso][i], test_labels, test_images)
      plt.subplot(num_rows, 2*num_cols, 2*i+2)     
      plot_value_array(i, predictions[caso][i], test_labels)
    plt.tight_layout()
    plt.show()
    print("\n\n")

pintar_conjunto_casos_con_predicciones(7,2,8)
# Out:
# ----------------------------------------------------------
# PREDICCIONES CASO  1  FIGURAS  7  x  2
# ----------------------------------------------------------
# PREDICCIONES CASO  2  FIGURAS  7  x  2
# ----------------------------------------------------------
# PREDICCIONES CASO  3  FIGURAS  7  x  2
# ----------------------------------------------------------
# PREDICCIONES CASO  4  FIGURAS  7  x  2
# ----------------------------------------------------------
# PREDICCIONES CASO  5  FIGURAS  7  x  2
# ----------------------------------------------------------
# PREDICCIONES CASO  6  FIGURAS  7  x  2
# ----------------------------------------------------------
# PREDICCIONES CASO  7  FIGURAS  7  x  2
# ----------------------------------------------------------
# PREDICCIONES CASO  8  FIGURAS  7  x  2

# %% [markdown]
# Cabria la pena destacar los siguientes casos, donde se equivoca:
# * CASO 1
#   - 7x1
# * CASO 2
#   - 7x1
# * CASO 3
#   - 3x1
#   - 4x1
#   - 4x2
#   - 6x1
#   - 6x2
#   - 7x1
# * CASO 5
#   - 7x1
# * CASO 6
#   - 7x1
# * CASO 7
#   - 7x1
# * CASO 8
#   - 7x1

# %% [markdown]
# ## Mejorar los modelos

# %% [markdown]
# * Podemos observar que la precisión obtenida de este modelo para estos datos (89% en el mejor de los casos) puede que no sea suficiente para un problema donde la precisión es importante (conducción automática).
# * Podríamos decir que es un resultado esperado, puesto que no hay una solución única para todos los problemas, sino que cada problema requiere su propia solución.
# * Ahora vamos a probar el optimizador `adam`. Recordemos que el
# optimizador es el algoritmo usado por el modelo para actualizar los pesos de cada una de sus capas en el proceso de entrenamiento. `Adam`, a veces, puede hacer converger mejor el proceso de optimización. Veámoslo:

# %%
# CASO DE USO CON OPTIMIZADOR ADAM
for caso in range(casos):
  model = Sequential()
  model.add(Flatten(input_shape=(28, 28)))
  model.add(Dense(numero_neuronas_primera_capa[caso], activation=funcion_activacion_primera_capa[caso]))
  model.add(Dense(10, activation='softmax'))
  models.append(model)

for caso in range(casos):
  models[caso].compile(optimizer='Adam', loss=funcion_perdida[caso], metrics=[metrica[caso]])

for caso in range(casos):
  print("CASO ",caso + 1)
  print("---------------------------------")
  print("NÚMERO NEURONAS PRIMERA CAPA: ",numero_neuronas_primera_capa[caso])
  print("FUNCIÓN ACTIVACIÓN PRIMERA CAPA: ",funcion_activacion_primera_capa[caso])
  print("FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax")
  print("OPTIMIZADOR: Adam")
  print("FUNCIÓN PÉRDIDA: ",funcion_perdida[caso])
  print("MÉTRICA: ",metrica[caso])
  print("---------------------------------")
  models[caso].fit(train_images, train_labels, epochs=numero_iteraciones[caso])
  print("\n\n")

test_loss = []
test_acc = []
for caso in range(casos):
  test_loss.append(models[caso].evaluate(test_images,  test_labels)[0])
  test_acc.append(models[caso].evaluate(test_images,  test_labels)[1])

for caso in range(casos):
  print("CASO ",caso + 1)
  print("---------------------------------")
  print("PERDIDA CON LOS DATOS DE TEST: ",test_loss[caso])
  print("PRECISIÓN CON LOS DATOS DE TEST: ",test_acc[caso])
  print("\n\n")
# Out:
# CASO  1
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  10
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  relu
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR: Adam
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4682 - accuracy: 0.8378
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4377 - accuracy: 0.8476
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4227 - accuracy: 0.8534
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4114 - accuracy: 0.8575
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4017 - accuracy: 0.8589
#
#
#
# CASO  2
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  10
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  relu
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR: Adam
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4098 - accuracy: 0.8572
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4031 - accuracy: 0.8597
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3969 - accuracy: 0.8616
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3922 - accuracy: 0.8634
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3891 - accuracy: 0.8634
#
#
#
# CASO  3
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  10
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR: Adam
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6115 - accuracy: 0.7986
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4934 - accuracy: 0.8325
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4526 - accuracy: 0.8432
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4297 - accuracy: 0.8498
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4148 - accuracy: 0.8546
#
#
#
# CASO  4
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  10
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR: Adam
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4153 - accuracy: 0.8538
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4056 - accuracy: 0.8569
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3975 - accuracy: 0.8594
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3920 - accuracy: 0.8606
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3853 - accuracy: 0.8635
#
#
#
# CASO  5
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  512
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  relu
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR: Adam
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4376 - accuracy: 0.8443
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3556 - accuracy: 0.8704
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3212 - accuracy: 0.8815
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2993 - accuracy: 0.8901
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2790 - accuracy: 0.8959
#
#
#
# CASO  6
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  512
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  relu
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR: Adam
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3066 - accuracy: 0.8902
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2801 - accuracy: 0.8973
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2647 - accuracy: 0.9021
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2506 - accuracy: 0.9071
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2410 - accuracy: 0.9098
#
#
#
# CASO  7
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  512
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR: Adam
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4639 - accuracy: 0.8317
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3797 - accuracy: 0.8623
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3405 - accuracy: 0.8747
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3136 - accuracy: 0.8839
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2918 - accuracy: 0.8909
#
#
#
# CASO  8
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  512
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR: Adam
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2847 - accuracy: 0.8966
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2659 - accuracy: 0.9015
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2508 - accuracy: 0.9058
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2364 - accuracy: 0.9120
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2252 - accuracy: 0.9152
#
#
#
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4305 - accuracy: 0.8498
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4305 - accuracy: 0.8498
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4391 - accuracy: 0.8453
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4391 - accuracy: 0.8453
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4482 - accuracy: 0.8411
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4482 - accuracy: 0.8411
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4332 - accuracy: 0.8467
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4332 - accuracy: 0.8467
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3403 - accuracy: 0.8783
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3403 - accuracy: 0.8783
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3360 - accuracy: 0.8860
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3360 - accuracy: 0.8860
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3390 - accuracy: 0.8774
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3390 - accuracy: 0.8774
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3148 - accuracy: 0.8900
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3148 - accuracy: 0.8900
# CASO  1
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.43047577142715454
# PRECISIÓN CON LOS DATOS DE TEST:  0.8497999906539917
#
#
#
# CASO  2
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.43914490938186646
# PRECISIÓN CON LOS DATOS DE TEST:  0.845300018787384
#
#
#
# CASO  3
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.4481604993343353
# PRECISIÓN CON LOS DATOS DE TEST:  0.8410999774932861
#
#
#
# CASO  4
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.4331766963005066
# PRECISIÓN CON LOS DATOS DE TEST:  0.8467000126838684
#
#
#
# CASO  5
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.34033164381980896
# PRECISIÓN CON LOS DATOS DE TEST:  0.8783000111579895
#
#
#
# CASO  6
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.336030513048172
# PRECISIÓN CON LOS DATOS DE TEST:  0.8859999775886536
#
#
#
# CASO  7
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.339012086391449
# PRECISIÓN CON LOS DATOS DE TEST:  0.8773999810218811
#
#
#
# CASO  8
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.31483128666877747
# PRECISIÓN CON LOS DATOS DE TEST:  0.8899999856948853

# %% [markdown]
# Como vemos, cambiando solo el optimizador ya hemos mejorado un  10% adicional la precisión del modelo, en el caso 3 y sobrepasando el 91% en el caso 8. Esto nos hace pensar que hay muchos elementos a tener en cuenta cuando definimos y configuramos el proceso de aprendizaje de
# una red neuronal. Con los datos de test, pasamos de un 87% en el caso 8 a un 89% (dos puntos porcentuales, en según que problemas, puede ser la diferencia entre que acepten el proyecto o no, y no digamos nada si nos jugamos miles de euros en una compatición de kaggle)

# %% [markdown]
# Veamos ahora el caso de subir el número de iteraciones a 25 para los casos 2 y 7

# %%
for caso in range(casos):
  if caso==1 or caso ==6:
    model = Sequential()
    model.add(Flatten(input_shape=(28, 28)))
    model.add(Dense(numero_neuronas_primera_capa[caso], activation=funcion_activacion_primera_capa[caso]))
    model.add(Dense(10, activation='softmax'))
    models.append(model)

for caso in range(casos):
  if caso==1 or caso ==6:
    models[caso].compile(optimizer=optimizador[caso], loss=funcion_perdida[caso], metrics=[metrica[caso]])

for caso in range(casos):
  if caso==1 or caso ==6:
    print("CASO ",caso + 1)
    print("---------------------------------")
    print("NÚMERO NEURONAS PRIMERA CAPA: ",numero_neuronas_primera_capa[caso])
    print("FUNCIÓN ACTIVACIÓN PRIMERA CAPA: ",funcion_activacion_primera_capa[caso])
    print("FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax")
    print("OPTIMIZADOR: ", optimizador[caso])
    print("FUNCIÓN PÉRDIDA: ",funcion_perdida[caso])
    print("MÉTRICA: ",metrica[caso])
    print("---------------------------------")
    models[caso].fit(train_images, train_labels, epochs=25)
    print("\n\n")

test_loss = []
test_acc = []
for caso in range(casos):
  if caso==1 or caso ==6:
    test_loss.append(models[caso].evaluate(test_images,  test_labels)[0])
    test_acc.append(models[caso].evaluate(test_images,  test_labels)[1])

for caso in range(2):
  print("CASO ",caso + 1)
  print("---------------------------------")
  print("PERDIDA CON LOS DATOS DE TEST: ",test_loss[caso])
  print("PRECISIÓN CON LOS DATOS DE TEST: ",test_acc[caso])
  print("\n\n")
# Out:
# CASO  2
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  10
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  relu
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  rmsprop
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3389 - accuracy: 0.8823
# Epoch 2/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3371 - accuracy: 0.8817
# Epoch 3/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3374 - accuracy: 0.8835
# Epoch 4/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3382 - accuracy: 0.8823
# Epoch 5/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3381 - accuracy: 0.8819
# Epoch 6/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3377 - accuracy: 0.8827
# Epoch 7/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3367 - accuracy: 0.8826
# Epoch 8/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3367 - accuracy: 0.8837
# Epoch 9/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3379 - accuracy: 0.8821
# Epoch 10/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3370 - accuracy: 0.8836
# Epoch 11/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3369 - accuracy: 0.8829
# Epoch 12/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3368 - accuracy: 0.8827
# Epoch 13/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3365 - accuracy: 0.8834
# Epoch 14/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3371 - accuracy: 0.8837
# Epoch 15/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3362 - accuracy: 0.8825
# Epoch 16/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3365 - accuracy: 0.8830
# Epoch 17/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3363 - accuracy: 0.8835
# Epoch 18/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3353 - accuracy: 0.8841
# Epoch 19/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3364 - accuracy: 0.8844
# Epoch 20/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3368 - accuracy: 0.8836
# Epoch 21/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3360 - accuracy: 0.8835
# Epoch 22/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3357 - accuracy: 0.8842
# Epoch 23/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3371 - accuracy: 0.8847
# Epoch 24/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3364 - accuracy: 0.8832
# Epoch 25/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3364 - accuracy: 0.8846
#
#
#
# CASO  7
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  512
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  sgd
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0621 - accuracy: 0.9795
# Epoch 2/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0609 - accuracy: 0.9801
# Epoch 3/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0600 - accuracy: 0.9807
# Epoch 4/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0592 - accuracy: 0.9808
# Epoch 5/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0586 - accuracy: 0.9811
# Epoch 6/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0581 - accuracy: 0.9814
# Epoch 7/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0575 - accuracy: 0.9816
# Epoch 8/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0572 - accuracy: 0.9819
# Epoch 9/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0568 - accuracy: 0.9816
# Epoch 10/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0565 - accuracy: 0.9820
# Epoch 11/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0561 - accuracy: 0.9820
# Epoch 12/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0559 - accuracy: 0.9822
# Epoch 13/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0556 - accuracy: 0.9821
# Epoch 14/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0554 - accuracy: 0.9821
# Epoch 15/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0551 - accuracy: 0.9821
# Epoch 16/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0550 - accuracy: 0.9826
# Epoch 17/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0547 - accuracy: 0.9825
# Epoch 18/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0545 - accuracy: 0.9827
# Epoch 19/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0543 - accuracy: 0.9823
# Epoch 20/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0541 - accuracy: 0.9826
# Epoch 21/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0540 - accuracy: 0.9827
# Epoch 22/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0538 - accuracy: 0.9827
# Epoch 23/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0536 - accuracy: 0.9826
# Epoch 24/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0535 - accuracy: 0.9829
# Epoch 25/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0533 - accuracy: 0.9828
#
#
#
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4694 - accuracy: 0.8500
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4694 - accuracy: 0.8500
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3655 - accuracy: 0.9023
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3655 - accuracy: 0.9023
# CASO  1
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.4694005846977234
# PRECISIÓN CON LOS DATOS DE TEST:  0.8500000238418579
#
#
#
# CASO  2
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.3654850721359253
# PRECISIÓN CON LOS DATOS DE TEST:  0.9023000001907349

# %% [markdown]
# En el siguiente gráfico vemos las conclusiones finales:

# %% [markdown]
# ![Grafico Final.png](data:image/png;base64,...)

# %% [markdown]
# Básicamente, lo que vemos es:
# * Para el caso inicial:
#   - Con los datos de entrenamiento:
#     * El que mejor se comporta con menos pérdida y mayor precisión es el caso 8 (89% de precisión)
#     * El que peor se comporta con mayor pérdida y menor precisión es el caso 3 (75% de precisión)
#   - Con los datos de Test se sigue dando esta circunstancia (bajando un 1 p.p. la precisión del caso 8)
# * Cuando metemos el optimizador Adam tenemos que:
#   - Con los datos de entrenamiento:
#     * El que mejor se comporta con menos pérdida y mayor precisión vuelve a ser el caso 8 mejorando en 3 p.p. la precisión (llegando al 92%)
#     * El que peor se comporta con mayor pérdida y menor precisión sigue siendo el caso 3 pero mejorando en 10 p.p. la precisión (hasta el 85%)
#   - Con los datos de Test se sigue dando esta circunstancia (mejorando un 1 p.p. la precisión del caso 8 para los datos de test con la configuración inicial, pero 8 p.p. para el caso peor que era el 3)
# * Para la configuración inicial y las 25 Iteraciones:
#   - Caso 2
#     * Para los datos de entrenamiento
#       - La pérdida baja 8 p.p.
#       - La precisión aumenta 2 p.p.
#     * Para los datos de Test
#       - La pérdida aumenta 1 p.p.
#       - La precisión aumenta 1 p.p.
#   - Caso 7
#     * Para los datos de entrenamiento
#       - La pérdida disminuye 50 p.p.
#       - La precisión aumenta 17 p.p. cosa que es espectacular
#     * Para los datos de Test
#       - La pérdida disminuye 19 p.p.
#       - La precisión aumenta 9 p.p. hasta el 90%

# %% [markdown]
# Hemos conseguido averiguar que el escenario que mejor nos funciona es el 8:
# * 512 neuronas en la primera capa
# * Función activación `sigmoid`
# * Optimizador `Adam`
# * 25 iteraciones de entrenamiento.
#
# Vamos a ver que datos nos acaba dando:

# %%
# %tensorflow_version 2.x
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten

from keras.utils.vis_utils import plot_model
# Out:
# 2.7.0

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images = train_images.astype('float32')
test_images = test_images.astype('float32')

train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
model = Sequential()
model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(512, activation='sigmoid'))
model.add(Dense(10, activation='softmax'))

plot_model(model, to_file='modeloFinal_plot.png', show_shapes=True)

# %%
model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=25)

test_loss, test_acc = model.evaluate(test_images,  test_labels)

print("CASO 8")
print("---------------------------------")
print("PERDIDA CON LOS DATOS DE TEST: ",test_loss)
print("PRECISIÓN CON LOS DATOS DE TEST: ",test_acc)
# Out:
# Epoch 1/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5040 - accuracy: 0.8199
# Epoch 2/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3832 - accuracy: 0.8609
# Epoch 3/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3437 - accuracy: 0.8741
# Epoch 4/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3148 - accuracy: 0.8844
# Epoch 5/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2943 - accuracy: 0.8903
# Epoch 6/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2754 - accuracy: 0.8966
# Epoch 7/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2600 - accuracy: 0.9018
# Epoch 8/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2462 - accuracy: 0.9074
# Epoch 9/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2328 - accuracy: 0.9126
# Epoch 10/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2207 - accuracy: 0.9172
# Epoch 11/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2104 - accuracy: 0.9209
# Epoch 12/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2016 - accuracy: 0.9249
# Epoch 13/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1919 - accuracy: 0.9272
# Epoch 14/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1846 - accuracy: 0.9308
# Epoch 15/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1772 - accuracy: 0.9338
# Epoch 16/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1688 - accuracy: 0.9361
# Epoch 17/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1615 - accuracy: 0.9402
# Epoch 18/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1544 - accuracy: 0.9420
# Epoch 19/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1489 - accuracy: 0.9435
# Epoch 20/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1426 - accuracy: 0.9466
# Epoch 21/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1375 - accuracy: 0.9483
# Epoch 22/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1327 - accuracy: 0.9496
# Epoch 23/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1274 - accuracy: 0.9522
# Epoch 24/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1217 - accuracy: 0.9545
# Epoch 25/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1169 - accuracy: 0.9564
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3919 - accuracy: 0.8832
# CASO 8
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.39190736413002014
# PRECISIÓN CON LOS DATOS DE TEST:  0.8831999897956848

# %% [markdown]
# * **Pérdida de 0,12 y precisión 96% con los datos de entrenamiento y pérdida de 0,36 y precisión del 90% con los datos de Test (esto es a lo máximo que, con lo que sabemos, podemos llegar). Veamos en la Práctica 2 que conseguimos con las Redes Neuronales Convolucionales...**

# %% [markdown]
# ## CUESTION OPCIONAL 1: RENDIMIENTO DE LOS MODELOS SEGÚN EL NÚMERO DE ITERACIONES

# %%
# %tensorflow_version 2.x
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten

print(tf.__version__)
# Out:
# 2.7.0

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images = train_images.astype('float32')
test_images = test_images.astype('float32')

train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
casos = 8
numero_neuronas_primera_capa = [10,10,10,10,512,512,512,512]
funcion_activacion_primera_capa = ['relu','relu','sigmoid','sigmoid','relu','relu','sigmoid','sigmoid']
optimizador =['sgd','rmsprop','sgd','rmsprop','sgd','rmsprop','sgd','rmsprop']
funcion_perdida = ['sparse_categorical_crossentropy', 'sparse_categorical_crossentropy','sparse_categorical_crossentropy',\
                   'sparse_categorical_crossentropy','sparse_categorical_crossentropy','sparse_categorical_crossentropy',\
                   'sparse_categorical_crossentropy','sparse_categorical_crossentropy']
numero_iteraciones = [5,5,5,5,5,5,5,5]
metrica = ['accuracy','accuracy','accuracy','accuracy','accuracy','accuracy','accuracy','accuracy']
models = []
historys = []

# %%
for caso in range(casos):
  model = Sequential()
  model.add(Flatten(input_shape=(28, 28)))
  model.add(Dense(numero_neuronas_primera_capa[caso], activation=funcion_activacion_primera_capa[caso]))
  model.add(Dense(10, activation='softmax'))
  models.append(model)

# %%
for caso in range(casos):
  models[caso].compile(optimizer=optimizador[caso], loss=funcion_perdida[caso], metrics=[metrica[caso]])

# %%
x_val = train_images[:10000]
partial_x_train = train_images[10000:]

y_val = train_labels[:10000]
partial_y_train = train_labels[10000:]

# %%
for caso in range(casos):
  print("CASO ",caso + 1)
  print("---------------------------------")
  print("NÚMERO NEURONAS PRIMERA CAPA: ",numero_neuronas_primera_capa[caso])
  print("FUNCIÓN ACTIVACIÓN PRIMERA CAPA: ",funcion_activacion_primera_capa[caso])
  print("FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax")
  print("OPTIMIZADOR: ",optimizador[caso])
  print("FUNCIÓN PÉRDIDA: ",funcion_perdida[caso])
  print("MÉTRICA: ",metrica[caso])
  print("---------------------------------")
  historys.append(models[caso].fit(partial_x_train, partial_y_train, epochs=20, batch_size = 512, validation_data = (x_val, y_val)))
  print("\n\n")
# Out:
# CASO  1
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  10
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  relu
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  sgd
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/20
# 98/98 [==============================] - 2s 7ms/step - loss: 2.0696 - accuracy: 0.2998 - val_loss: 1.9006 - val_accuracy: 0.4028
# Epoch 2/20
# 98/98 [==============================] - 0s 5ms/step - loss: 1.7545 - accuracy: 0.4696 - val_loss: 1.6135 - val_accuracy: 0.5101
# Epoch 3/20
# 98/98 [==============================] - 0s 5ms/step - loss: 1.4721 - accuracy: 0.5432 - val_loss: 1.3281 - val_accuracy: 0.5635
# Epoch 4/20
# 98/98 [==============================] - 0s 5ms/step - loss: 1.2061 - accuracy: 0.6205 - val_loss: 1.0910 - val_accuracy: 0.6717
# Epoch 5/20
# 98/98 [==============================] - 0s 5ms/step - loss: 1.0185 - accuracy: 0.6795 - val_loss: 0.9555 - val_accuracy: 0.6909
# Epoch 6/20
# 98/98 [==============================] - 0s 5ms/step - loss: 0.9180 - accuracy: 0.6943 - val_loss: 0.8815 - val_accuracy: 0.7041
# Epoch 7/20
# 98/98 [==============================] - 0s 5ms/step - loss: 0.8558 - accuracy: 0.7075 - val_loss: 0.8314 - val_accuracy: 0.7173
# Epoch 8/20
# 98/98 [==============================] - 0s 5ms/step - loss: 0
20
# 98/98 [==============================] - 1s 5ms/step - loss: 0.4063 - accuracy: 0.8575 - val_loss: 0.4368 - val_accuracy: 0.8469
# Epoch 19/20
# 98/98 [==============================] - 1s 5ms/step - loss: 0.4032 - accuracy: 0.8605 - val_loss: 0.4317 - val_accuracy: 0.8529
# Epoch 20/20
# 98/98 [==============================] - 1s 5ms/step - loss: 0.4007 - accuracy: 0.8611 - val_loss: 0.4220 - val_accuracy: 0.8554
#
#
#
# CASO  3
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  10
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  sgd
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/20
# 98/98 [==============================] - 1s 7ms/step - loss: 2.3769 - accuracy: 0.1008 - val_loss: 2.2809 - val_accuracy: 0.1111
# Epoch 2/20
# 98/98 [==============================] - 1s 6ms/step - loss: 2.2384 - accuracy: 0.1713 - val_loss: 2.2022 - val_accuracy: 0.2761
# Epoch 3/20
# 98/98 [==============================] - 0s 5ms/step - loss: 2.1672 - accuracy: 0.3156 - val_loss: 2.1346 - val_accuracy: 0.3451
# Epoch 4/20
# 98/98 [==============================] - 1s 6ms/step - loss: 2.1016 - accuracy: 0.3846 - val_loss: 2.0709 - val_accuracy: 0.4250
# Epoch 5/20
# 98/98 [==============================] - 0s 5ms/step - loss: 2.0406 - accuracy: 0.4583 - val_loss: 2.0122 - val_accuracy: 0.4837
# Epoch 6/20
# 98/98 [==============================] - 0s 5ms/step - loss: 1.9836 - accuracy: 0.5060 - val_loss: 1.9567 - val_accuracy: 0.5223
# Epoch 7/20
# 98/98 [==============================] - 0s 5ms/step - loss: 1.9293 - accuracy: 0.5399 - val_loss: 1.9035 - val_accuracy: 0.5495
# Epoch 8/20
# 98/98 [==============================] - 1s 5ms/step - loss: 1.8769 - accuracy: 0.5610 - val_loss: 1.8521 - val_accuracy: 0.5661
# Epoch 9/20
# 98/98 [==============================] - 0s 5ms/step - loss: 1.8264 - accuracy: 0.5760 - val_loss: 1.8025 - val_accuracy: 0.5799
# Epoch 10/20
# 98/98 [==============================] - 0s 5ms/step - loss: 1.7775 - accuracy: 0.5876 - val_loss: 1.7545 - val_accuracy: 0.5881
# Epoch 11/20
# 98/98 [==============================] - 1s 5ms/step - loss: 1.7304 - accuracy: 0.5985 - val_loss: 1.7083 - val_accuracy: 0.5968
# Epoch 12/20
# 98/98 [==============================] - 1s 5ms/step - loss: 1.6850 - accuracy: 0.6062 - val_loss: 1.6638 - val_accuracy: 0.6052
# Epoch 13/20
# 98/98 [==============================] - 0s 5ms/step - loss: 1.6414 - accuracy: 0.6142 - val_loss: 1.6211 - val_accuracy: 0.6132
# Epoch 14/20
# 98/98 [==============================] - 1s 5ms/step - loss: 1.5996 - accuracy: 0.6219 - val_loss: 1.5802 - val_accuracy: 0.6227
# Epoch 15/20
# 98/98 [==============================] - 1s 9ms/step - loss: 1.5596 - accuracy: 0.6300 - val_loss: 1.5411 - val_accuracy: 0.6304
# Epoch 16/20
# 98/98 [==============================] - 1s 6ms/step - loss: 1.5213 - accuracy: 0.6370 - val_loss: 1.5037 - val_accuracy: 0.6380
# Epoch 17/20
# 98/98 [==============================] - 1s 5ms/step - loss: 1.4849 - accuracy: 0.6439 - val_loss: 1.4682 - val_accuracy: 0.6441
# Epoch 18/20
# 98/98 [==============================] - 1s 5ms/step - loss: 1.4503 - accuracy: 0.6496 - val_loss: 1.4344 - val_accuracy: 0.6512
# Epoch 19/20
# 98/98 [==============================] - 0s 5ms/step - loss: 1.4173 - accuracy: 0.6551 - val_loss: 1.4022 - val_accuracy: 0.6583
# Epoch 20/20
# 98/98 [==============================] - 1s 5ms/step - loss: 1.3860 - accuracy: 0.6611 - val_loss: 1.3717 - val_accuracy: 0.6629
#
#
#
# CASO  4
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  10
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  rmsprop
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/20
# 98/98 [==============================] - 1s 8ms/step - loss: 1.8801 - accuracy: 0.4065 - val_loss: 1.6165 - val_accuracy: 0.5390
# Epoch 2/20
# 98/98 [==============================] - 1s 6ms/step - loss: 1.4718 - accuracy: 0.6136 - val_loss: 1.3440 - val_accuracy: 0.6489
# Epoch 3/20
# 98/98 [==============================] - 1s 6ms/step - loss: 1.2453 - accuracy: 0.6785 - val_loss: 1.1529 - val_accuracy: 0.6988
# Epoch 4/20
# 98/98 [==============================] - 1s 6ms/step - loss: 1.0785 - accuracy: 0.7116 - val_loss: 1.0086 - val_accuracy: 0.7225
# Epoch 5/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.9505 - accuracy: 0.7422 - val_loss: 0.8979 - val_accuracy: 0.7702
# Epoch 6/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.8517 - accuracy: 0.7858 - val_loss: 0.8132 - val_accuracy: 0.7879
# Epoch 7/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.7743 - accuracy: 0.7989 - val_loss: 0.7446 - val_accuracy: 0.7988
# Epoch 8/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.7125 - accuracy: 0.8072 - val_loss: 0.6919 - val_accuracy: 0.8074
# Epoch 9/20
# 98/98 [==============================] - 1s 5ms/step - loss: 0.6630 - accuracy: 0.8154 - val_loss: 0.6481 - val_accuracy: 0.8132
# Epoch 10/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.6222 - accuracy: 0.8197 - val_loss: 0.6124 - val_accuracy: 0.8199
# Epoch 11/20
# 98/98 [==============================] - 1s 5ms/step - loss: 0.5892 - accuracy: 0.8248 - val_loss: 0.5865 - val_accuracy: 0.8190
# Epoch 12/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.5621 - accuracy: 0.8286 - val_loss: 0.5610 - val_accuracy: 0.8235
# Epoch 13/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.5393 - accuracy: 0.8322 - val_loss: 0.5410 - val_accuracy: 0.8282
# Epoch 14/20
# 98/98 [==============================] - 1s 5ms/step - loss: 0.5202 - accuracy: 0.8348 - val_loss: 0.5242 - val_accuracy: 0.8293
# Epoch 15/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.5040 - accuracy: 0.8384 - val_loss: 0.5101 - val_accuracy: 0.8328
# Epoch 16/20
# 98/98 [==============================] - 1s 5ms/step - loss: 0.4899 - accuracy: 0.8395 - val_loss: 0.4961 - val_accuracy: 0.8365
# Epoch 17/20
# 98/98 [==============================] - 1s 5ms/step - loss: 0.4777 - accuracy: 0.8430 - val_loss: 0.4888 - val_accuracy: 0.8347
# Epoch 18/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.4673 - accuracy: 0.8455 - val_loss: 0.4799 - val_accuracy: 0.8377
# Epoch 19/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.4582 - accuracy: 0.8476 - val_loss: 0.4702 - val_accuracy: 0.8406
# Epoch 20/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.4500 - accuracy: 0.8488 - val_loss: 0.4661 - val_accuracy: 0.8413
#
#
#
# CASO  5
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  512
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  relu
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  sgd
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/20
# 98/98 [==============================] - 1s 8ms/step - loss: 1.5560 - accuracy: 0.5656 - val_loss: 1.1579 - val_accuracy: 0.6716
# Epoch 2/20
# 98/98 [==============================] - 1s 7ms/step - loss: 1.0198 - accuracy: 0.6972 - val_loss: 0.9210 - val_accuracy: 0.7125
# Epoch 3/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.8616 - accuracy: 0.7352 - val_loss: 0.8164 - val_accuracy: 0.7478
# Epoch 4/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0
20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.2423 - accuracy: 0.9097 - val_loss: 0.3065 - val_accuracy: 0.8855
# Epoch 15/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.2350 - accuracy: 0.9128 - val_loss: 0.3057 - val_accuracy: 0.8914
# Epoch 16/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.2257 - accuracy: 0.9157 - val_loss: 0.3099 - val_accuracy: 0.8873
# Epoch 17/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.2216 - accuracy: 0.9164 - val_loss: 0.2925 - val_accuracy: 0.8968
# Epoch 18/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.2117 - accuracy: 0.9222 - val_loss: 0.2914 - val_accuracy: 0.8949
# Epoch 19/20
# 98/98 [==============================] - 1s 7ms/step - loss: 0.2083 - accuracy: 0.9222 - val_loss: 0.3095 - val_accuracy: 0.8892
# Epoch 20/20
# 98/98 [==============================] - 1s 7ms/step - loss: 0.2007 - accuracy: 0.9254 - val_loss: 0.3024 - val_accuracy: 0.8924
#
#
#
# CASO  7
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  512
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  sgd
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/20
# 98/98 [==============================] - 1s 8ms/step - loss: 2.1203 - accuracy: 0.3946 - val_loss: 1.9528 - val_accuracy: 0.5946
# Epoch 2/20
# 98/98 [==============================] - 1s 6ms/step - loss: 1.8337 - accuracy: 0.6160 - val_loss: 1.7125 - val_accuracy: 0.6454
# Epoch 3/20
# 98/98 [==============================] - 1s 7ms/step - loss: 1.6238 - accuracy: 0.6588 - val_loss: 1.5291 - val_accuracy: 0.6725
# Epoch 4/20
# 98/98 [==============================] - 1s 6ms/step - loss: 1.4632 - accuracy: 0.6788 - val_loss: 1.3892 - val_accuracy: 0.6925
# Epoch 5/20
# 98/98 [==============================] - 1s 6ms/step - loss: 1.3395 - accuracy: 0.6932 - val_loss: 1.2806 - val_accuracy: 0.7002
# Epoch 6/20
# 98/98 [==============================] - 1s 6ms/step - loss: 1.2429 - accuracy: 0.7018 - val_loss: 1.1960 - val_accuracy: 0.7060
# Epoch 7/20
# 98/98 [==============================] - 1s 6ms/step - loss: 1.1660 - accuracy: 0.7077 - val_loss: 1.1272 - val_accuracy: 0.7093
# Epoch 8/20
# 98/98 [==============================] - 1s 6ms/step - loss: 1.1038 - accuracy: 0.7123 - val_loss: 1.0720 - val_accuracy: 0.7211
# Epoch 9/20
# 98/98 [==============================] - 1s 7ms/step - loss: 1.0522 - accuracy: 0.7183 - val_loss: 1.0246 - val_accuracy: 0.7229
# Epoch 10/20
# 98/98 [==============================] - 1s 6ms/step - loss: 1.0090 - accuracy: 0.7226 - val_loss: 0.9864 - val_accuracy: 0.7264
# Epoch 11/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.9721 - accuracy: 0.7256 - val_loss: 0.9520 - val_accuracy: 0.7299
# Epoch 12/20
# 98/98 [==============================] - 1s 7ms/step - loss: 0.9404 - accuracy: 0.7289 - val_loss: 0.9235 - val_accuracy: 0.7338
# Epoch 13/20
# 98/98 [==============================] - 1s 7ms/step - loss: 0.9129 - accuracy: 0.7320 - val_loss: 0.8983 - val_accuracy: 0.7325
# Epoch 14/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.8886 - accuracy: 0.7341 - val_loss: 0.8752 - val_accuracy: 0.7376
# Epoch 15/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.8672 - accuracy: 0.7375 - val_loss: 0.8551 - val_accuracy: 0.7396
# Epoch 16/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.8480 - accuracy: 0.7391 - val_loss: 0.8373 - val_accuracy: 0.7430
# Epoch 17/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.8309 - accuracy: 0.7419 - val_loss: 0.8213 - val_accuracy: 0.7445
# Epoch 18/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.8154 - accuracy: 0.7431 - val_loss: 0.8065 - val_accuracy: 0.7451
# Epoch 19/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.8012 - accuracy: 0.7458 - val_loss: 0.7934 - val_accuracy: 0.7478
# Epoch 20/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.7884 - accuracy: 0.7480 - val_loss: 0.7812 - val_accuracy: 0.7505
#
#
#
# CASO  8
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  512
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  rmsprop
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/20
# 98/98 [==============================] - 1s 8ms/step - loss: 0.8238 - accuracy: 0.7245 - val_loss: 0.5785 - val_accuracy: 0.7969
# Epoch 2/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.5346 - accuracy: 0.8076 - val_loss: 0.5035 - val_accuracy: 0.8216
# Epoch 3/20
# 98/98 [==============================] - 1s 7ms/step - loss: 0.4762 - accuracy: 0.8276 - val_loss: 0.4677 - val_accuracy: 0.8301
# Epoch 4/20
# 98/98 [==============================] - 1s 7ms/step - loss: 0.4471 - accuracy: 0.8374 - val_loss: 0.4582 - val_accuracy: 0.8324
# Epoch 5/20
# 98/98 [==============================] - 1s 7ms/step - loss: 0.4241 - accuracy: 0.8460 - val_loss: 0.4124 - val_accuracy: 0.8537
# Epoch 6/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.4090 - accuracy: 0.8519 - val_loss: 0.4140 - val_accuracy: 0.8512
# Epoch 7/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.3940 - accuracy: 0.8572 - val_loss: 0.4110 - val_accuracy: 0.8534
# Epoch 8/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.3805 - accuracy: 0.8604 - val_loss: 0.3836 - val_accuracy: 0.8617
# Epoch 9/20
# 98/98 [==============================] - 1s 7ms/step - loss: 0.3703 - accuracy: 0.8648 - val_loss: 0.4199 - val_accuracy: 0.8464
# Epoch 10/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.3603 - accuracy: 0.8678 - val_loss: 0.3831 - val_accuracy: 0.8606
# Epoch 11/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.3524 - accuracy: 0.8709 - val_loss: 0.3713 - val_accuracy: 0.8673
# Epoch 12/20
# 98/98 [==============================] - 1s 7ms/step - loss: 0.3443 - accuracy: 0.8737 - val_loss: 0.3579 - val_accuracy: 0.8719
# Epoch 13/20
# 98/98 [==============================] - 1s 7ms/step - loss: 0.3360 - accuracy: 0.8766 - val_loss: 0.3769 - val_accuracy: 0.8592
# Epoch 14/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.3301 - accuracy: 0.8788 - val_loss: 0.3587 - val_accuracy: 0.8685
# Epoch 15/20
# 98/98 [==============================] - 1s 7ms/step - loss: 0.3227 - accuracy: 0.8833 - val_loss: 0.3473 - val_accuracy: 0.8730
# Epoch 16/20
# 98/98 [==============================] - 1s 7ms/step - loss: 0.3159 - accuracy: 0.8838 - val_loss: 0.3492 - val_accuracy: 0.8732
# Epoch 17/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.3101 - accuracy: 0.8868 - val_loss: 0.3510 - val_accuracy: 0.8714
# Epoch 18/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.3048 - accuracy: 0.8873 - val_loss: 0.3598 - val_accuracy: 0.8697
# Epoch 19/20
# 98/98 [==============================] - 1s 7ms/step - loss: 0.3005 - accuracy: 0.8903 - val_loss: 0.3447 - val_accuracy: 0.8710
# Epoch 20/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.2948 - accuracy: 0.8915 - val_loss: 0.3420 - val_accuracy: 0.8793

# %%
for caso in range(casos):
  print("CASO ",caso + 1)
  print("---------------------------------")
  print("NÚMERO NEURONAS PRIMERA CAPA: ",numero_neuronas_primera_capa[caso])
  print("FUNCIÓN ACTIVACIÓN PRIMERA CAPA: ",funcion_activacion_primera_capa[caso])
  print("FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax")
  print("OPTIMIZADOR: ",optimizador[caso])
  print("FUNCIÓN PÉRDIDA: ",funcion_perdida[caso])
  print("MÉTRICA: ",metrica[caso])
  print("---------------------------------")
  history_dict = historys[caso].history
  history_dict.keys()
  print(history_dict['loss'])
  print(history_dict['accuracy'])
  print(history_dict['val_loss'])
  print(history_dict['val_accuracy'])
  accuracy = historys[caso].history['accuracy']
  val_accuracy = historys[caso].history['val_accuracy']
  loss = historys[caso ].history['loss']
  val_loss = historys[caso].history['val_loss']
  epochs = range(1, len(accuracy) + 1)
  plt.plot(epochs, loss, 'bo', label='Pérdida de Entrenamiento')
  plt.plot(epochs, val_loss, 'b', label='Pérdida de Validación')
  plt.title('Pérdida de Entrenamiento y Validación')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.show()
# [0.5784845948219299, 0.5035492777824402, 0.46771615743637085, 0.4582068920135498, 0.4123978912830353, 0.41398885846138, 0.41099345684051514, 0.38363561034202576, 0.41993510723114014, 0.38307538628578186, 0.37128356099128723, 0.35786813497543335, 0.3769398033618927, 0.35865700244903564, 0.34728190302848816, 0.3491855561733246, 0.3510141670703888, 0.35982662439346313, 0.3447383642196655, 0.3419647812843323]
# [0.7968999743461609, 0.8216000199317932, 0.8300999999046326, 0.8324000239372253, 0.8536999821662903, 0.8511999845504761, 0.8533999919891357, 0.8616999983787537, 0.8464000225067139, 0.8605999946594238, 0.8672999739646912, 0.8719000220298767, 0.8592000007629395, 0.8684999942779541, 0.8730000257492065, 0.873199999332428, 0.871399998664856, 0.869700014591217, 0.8709999918937683, 0.8792999982833862]

# %%
test_loss = []
test_acc = []
for caso in range(casos):
  test_loss.append(models[caso].evaluate(test_images,  test_labels)[0])
  test_acc.append(models[caso].evaluate(test_images,  test_labels)[1])
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6298 - accuracy: 0.7815
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6298 - accuracy: 0.7815
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4492 - accuracy: 0.8448
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4492 - accuracy: 0.8448
# 313/313 [==============================] - 1s 3ms/step - loss: 1.3788 - accuracy: 0.6576
# 313/313 [==============================] - 1s 3ms/step - loss: 1.3788 - accuracy: 0.6576
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4911 - accuracy: 0.8328
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4911 - accuracy: 0.8328
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5408 - accuracy: 0.8187
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5408 - accuracy: 0.8187
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3387 - accuracy: 0.8852
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3387 - accuracy: 0.8852
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7941 - accuracy: 0.7449
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7941 - accuracy: 0.7449
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3707 - accuracy: 0.8677
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3707 - accuracy: 0.8677

# %%
for caso in range(casos):
  print("CASO ",caso + 1)
  print("---------------------------------")
  print("PERDIDA CON LOS DATOS DE TEST: ",test_loss[caso])
  print("PRECISIÓN CON LOS DATOS DE TEST: ",test_acc[caso])
  print("\n\n")
# Out:
# CASO  1
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.6298120021820068
# PRECISIÓN CON LOS DATOS DE TEST:  0.781499981880188
#
#
#
# CASO  2
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.4492059051990509
# PRECISIÓN CON LOS DATOS DE TEST:  0.8447999954223633
#
#
#
# CASO  3
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  1.378839135169983
# PRECISIÓN CON LOS DATOS DE TEST:  0.6575999855995178
#
#
#
# CASO  4
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.4911060929298401
# PRECISIÓN CON LOS DATOS DE TEST:  0.8327999711036682
#
#
#
# CASO  5
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.5408041477203369
# PRECISIÓN CON LOS DATOS DE TEST:  0.8187000155448914
#
#
#
# CASO  6
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.33865609765052795
# PRECISIÓN CON LOS DATOS DE TEST:  0.885200023651123
#
#
#
# CASO  7
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.7940651774406433
# PRECISIÓN CON LOS DATOS DE TEST:  0.7448999881744385
#
#
#
# CASO  8
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.370734840631485
# PRECISIÓN CON LOS DATOS DE TEST:  0.8676999807357788

# %% [markdown]
# ## CUESTIÓN OPCIONAL 2: MATRIZ DE CONFUSIÓN DE LOS MODELOS

# %%
# %tensorflow_version 2.x
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten

from keras.utils.np_utils import to_categorical

from collections import Counter
from sklearn.metrics import confusion_matrix
import itertools

print(tf.__version__)
# Out:
# 2.7.0

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images = train_images.astype('float32')
test_images = test_images.astype('float32')

train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
casos = 8
numero_neuronas_primera_capa = [10,10,10,10,512,512,512,512]
funcion_activacion_primera_capa = ['relu','relu','sigmoid','sigmoid','relu','relu','sigmoid','sigmoid']
optimizador =['sgd','rmsprop','sgd','rmsprop','sgd','rmsprop','sgd','rmsprop']
funcion_perdida = ['sparse_categorical_crossentropy', 'sparse_categorical_crossentropy','sparse_categorical_crossentropy',\
                   'sparse_categorical_crossentropy','sparse_categorical_crossentropy','sparse_categorical_crossentropy',\
                   'sparse_categorical_crossentropy','sparse_categorical_crossentropy']
numero_iteraciones = [5,5,5,5,5,5,5,5]
metrica = ['accuracy','accuracy','accuracy','accuracy','accuracy','accuracy','accuracy','accuracy']
models = []
historys = []

# %%
for caso in range(casos):
  model = Sequential()
  model.add(Flatten(input_shape=(28, 28)))
  model.add(Dense(numero_neuronas_primera_capa[caso], activation=funcion_activacion_primera_capa[caso]))
  model.add(Dense(10, activation='softmax'))
  models.append(model)

# %%
for caso in range(casos):
  models[caso].compile(optimizer=optimizador[caso], loss=funcion_perdida[caso], metrics=[metrica[caso]])

# %%
for caso in range(casos):
  print("CASO ",caso + 1)
  print("---------------------------------")
  print("NÚMERO NEURONAS PRIMERA CAPA: ",numero_neuronas_primera_capa[caso])
  print("FUNCIÓN ACTIVACIÓN PRIMERA CAPA: ",funcion_activacion_primera_capa[caso])
  print("FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax")
  print("OPTIMIZADOR: ",optimizador[caso])
  print("FUNCIÓN PÉRDIDA: ",funcion_perdida[caso])
  print("MÉTRICA: ",metrica[caso])
  print("---------------------------------")
  models[caso].fit(train_images, train_labels, epochs=numero_iteraciones[caso])
  print("\n\n")
# Out:
# CASO  1
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  10
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  relu
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  sgd
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.9333 - accuracy: 0.6852
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5842 - accuracy: 0.7992
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5255 - accuracy: 0.8189
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4961 - accuracy: 0.8281
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4779 - accuracy: 0.8340
#
#
#
# CASO  2
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  10
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  relu
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  rmsprop
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6215 - accuracy: 0.7886
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4660 - accuracy: 0.8393
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4379 - accuracy: 0.8490
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4233 - accuracy: 0.8548
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4139 - accuracy: 0.8577
#
#
#
# CASO  3
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  10
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  sgd
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.8074 - accuracy: 0.4307
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.2699 - accuracy: 0.6166
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.0174 - accuracy: 0.6914
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.8839 - accuracy: 0.7117
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.8028 - accuracy: 0.7236
#
#
#
# CASO  4
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  10
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  rmsprop
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.9688 - accuracy: 0.7330
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5283 - accuracy: 0.8223
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4653 - accuracy: 0.8375
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4390 - accuracy: 0.8456
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4231 - accuracy: 0.8507
#
#
#
# CASO  5
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  512
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  relu
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  sgd
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.7109 - accuracy: 0.7729
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4978 - accuracy: 0.8310
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4554 - accuracy: 0.8433
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4310 - accuracy: 0.8511
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4129 - accuracy: 0.8568
#
#
#
# CASO  6
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  512
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  relu
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  rmsprop
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4947 - accuracy: 0.8227
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3817 - accuracy: 0.8653
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3557 - accuracy: 0.8780
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3395 - accuracy: 0.8848
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3300 - accuracy: 0.8894
#
#
#
# CASO  7
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  512
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  sgd
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.1446 - accuracy: 0.6767
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.7086 - accuracy: 0.7608
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6227 - accuracy: 0.7837
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5763 - accuracy: 0.8004
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5461 - accuracy: 0.8093
#
#
#
# CASO  8
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  512
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  rmsprop
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# Epoch 1/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5053 - accuracy: 0.8177
# Epoch 2/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3831 - accuracy: 0.8606
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3438 - accuracy: 0.8752
# Epoch 4/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3202 - accuracy: 0.8821
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3015 - accuracy: 0.8895

# %%
test_loss = []
test_acc = []
for caso in range(casos):
  test_loss.append(models[caso].evaluate(test_images,  test_labels)[0])
  test_acc.append(models[caso].evaluate(test_images,  test_labels)[1])
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5025 - accuracy: 0.8249
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5025 - accuracy: 0.8249
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4704 - accuracy: 0.8399
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4704 - accuracy: 0.8399
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7865 - accuracy: 0.7199
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7865 - accuracy: 0.7199
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4574 - accuracy: 0.8387
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4574 - accuracy: 0.8387
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4356 - accuracy: 0.8491
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4356 - accuracy: 0.8491
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5152 - accuracy: 0.8540
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5152 - accuracy: 0.8540
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5526 - accuracy: 0.8038
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5526 - accuracy: 0.8038
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3868 - accuracy: 0.8684
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3868 - accuracy: 0.8684

# %%
for caso in range(casos):
  print("CASO ",caso + 1)
  print("---------------------------------")
  print("PERDIDA CON LOS DATOS DE TEST: ",test_loss[caso])
  print("PRECISIÓN CON LOS DATOS DE TEST: ",test_acc[caso])
  print("\n\n")
# Out:
# CASO  1
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.5024704337120056
# PRECISIÓN CON LOS DATOS DE TEST:  0.8248999714851379
#
#
#
# CASO  2
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.4704027473926544
# PRECISIÓN CON LOS DATOS DE TEST:  0.839900016784668
#
#
#
# CASO  3
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.7864617705345154
# PRECISIÓN CON LOS DATOS DE TEST:  0.7199000120162964
#
#
#
# CASO  4
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.4573606550693512
# PRECISIÓN CON LOS DATOS DE TEST:  0.838699996471405
#
#
#
# CASO  5
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.4356127083301544
# PRECISIÓN CON LOS DATOS DE TEST:  0.8490999937057495
#
#
#
# CASO  6
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.5151560306549072
# PRECISIÓN CON LOS DATOS DE TEST:  0.8539999723434448
#
#
#
# CASO  7
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.5525870323181152
# PRECISIÓN CON LOS DATOS DE TEST:  0.8037999868392944
#
#
#
# CASO  8
# ---------------------------------
# PERDIDA CON LOS DATOS DE TEST:  0.38681861758232117
# PRECISIÓN CON LOS DATOS DE TEST:  0.868399977684021

# %%
# Look at confusion matrix 
# Note, this code is taken straight from the SKLEARN website, an nice way of 
# viewing confusion matrix.
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Observación')
    plt.xlabel('Predicción')

# %%
test_labelsp = to_categorical(test_labels)
for caso in range(casos):
  print("CASO ",caso + 1)
  print("---------------------------------")
  print("NÚMERO NEURONAS PRIMERA CAPA: ",numero_neuronas_primera_capa[caso])
  print("FUNCIÓN ACTIVACIÓN PRIMERA CAPA: ",funcion_activacion_primera_capa[caso])
  print("FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax")
  print("OPTIMIZADOR: ",optimizador[caso])
  print("FUNCIÓN PÉRDIDA: ",funcion_perdida[caso])
  print("MÉTRICA: ",metrica[caso])
  print("---------------------------------")
  # Predict the values from the validation dataset
  Y_pred = models[caso].predict(test_images)
  # Convert predictions classes to one hot vectors 
  Y_pred_classes = np.argmax(Y_pred, axis = 1) 
  # Convert validation observations to one hot vectors
  Y_true = np.argmax(test_labelsp, axis = 1) 
  # compute the confusion matrix
  confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)
  # plot the confusion matrix
  plot_confusion_matrix(confusion_mtx, classes = range(10))
  plt.show()
  print("\n\n")
# Out:
# CASO  1
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  10
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  relu
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  sgd
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# CASO  2
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  10
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  relu
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  rmsprop
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# CASO  3
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  10
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  sgd
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# CASO  4
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  10
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  rmsprop
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# CASO  5
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  512
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  relu
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  sgd
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# CASO  6
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  512
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  relu
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  rmsprop
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# CASO  7
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  512
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  sgd
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------
# CASO  8
# ---------------------------------
# NÚMERO NEURONAS PRIMERA CAPA:  512
# FUNCIÓN ACTIVACIÓN PRIMERA CAPA:  sigmoid
# FUNCIÓN ACTIVACIÓN ULTIMA CAPA: softmax
# OPTIMIZADOR:  rmsprop
# FUNCIÓN PÉRDIDA:  sparse_categorical_crossentropy
# MÉTRICA:  accuracy
# ---------------------------------

# %% [markdown]
# ---
